# %% [markdown]
# # 3/4: Data preprocessing 2
# By Niloufar Shahdoust (niloufar.shahdoust@utah.edu)

# %%
import os
import mat73
import numpy as np
import pandas as pd
import random
from matplotlib import cm
from matplotlib import colormaps
from ast import literal_eval
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from visbrain.objects import BrainObj, SceneObj, SourceObj
from matplotlib.colors import to_hex
from PIL import Image
from colorsys import hsv_to_rgb

# %% [markdown]
# ## reading data

# %%
input_folder = '2_brain_visualization_preProcessing_1'
output_folder = '3_brain_visualization_preProcessing_2'

os.makedirs(output_folder, exist_ok=True)
# Collect all CSV files from the input folder
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

# Load data into DataFrames
df_patients = []
for file_name in csv_files:
    file_path = os.path.join(input_folder, file_name)
    df = pd.read_csv(file_path)
    df_patients.append(df)

# Generate a colormap for regions
area_per_patient = [df['area'].unique() for df in df_patients]
area_all_patients = pd.unique(np.concatenate(area_per_patient)).tolist()



num_colors = len(area_all_patients)

# high saturation prevents gray colors
colors = [
    hsv_to_rgb(i / num_colors, 0.90, 0.90)
    for i in range(num_colors)
]

region_colors = {
    region: to_hex(colors[i])
    for i, region in enumerate(area_all_patients)
}

# %% [markdown]
# ## taking a look at areas

# %%
region_colors
# Out:
# {'MFG': '#e61717',
#  'MTG': '#e64917',
#  'CG': '#e67a17',
#  'IFG': '#e6ac17',
#  'OrG': '#e6dd17',
#  'Hipp': '#bce617',
#  'Str': '#8be617',
#  'FuG': '#59e617',
#  'PhG': '#27e617',
#  'ITG': '#17e638',
#  'Amyg': '#17e66a',
#  'SFG': '#17e69b',
#  'Cun': '#17e6cd',
#  'STG': '#17cde6',
#  'INS': '#179be6',
#  'PrG': '#176ae6',
#  'PoG': '#1738e6',
#  'SPL': '#2717e6',
#  'Pcun': '#5917e6',
#  'IPL': '#8b17e6',
#  'Tha': '#bc17e6',
#  'pSTS': '#e617dd',
#  'PCL': '#e617ac',
#  'OcG': '#e6177a',
#  'sOcG': '#e61749'}

# %% [markdown]
# ## preprocessing 2:
# I want to take a couple of brain areas ONLY and save those areas for each patient.

# %%
df_patients[0].head()
# Out:
#   Channel_Name  Nmm_atlas  left  right area  coordinate_x  coordinate_y  \
# 0        ROFC7  Right MFG     0      1  MFG     37.716870     32.353153
# 1       LOFC10   Left MFG     1      0  MFG    -34.614600     33.788637
# 2        RCD10  Right MFG     0      1  MFG     49.315260     21.861680
# 3        LHIP9   Left MTG     1      0  MTG    -63.272704    -14.200921
# 4        ROFC8  Right MFG     0      1  MFG     38.234987     30.466426
#
#    coordinate_z
# 0     13.918516
# 1     28.812653
# 2     33.689576
# 3    -18.179159
# 4     19.424250

# %%
input_folder = '2_brain_visualization_preProcessing_1'
output_folder = '3_brain_visualization_preProcessing_2'


##List of specific areas to keep

target_areas = [
    "Hipp",
    "MTG",
    "OrG",
    "MFG",
    "CG",
    "STG",
    "FuG",
    "Amyg",
    "IFG",
    "SFG",
    "ITG",
    "INS",
    "Str",
    "Tha",
    "PrG",
    "PhG",
    "IPL",
    "PoG",
    "pSTS",
    "SPL"
]


# target_areas = [
#     "Hippocampus"
# ]



# Get list of CSV files in the input folder
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

# Process each CSV file
for file_name in csv_files:
    file_path = os.path.join(input_folder, file_name)
    
    # Load the CSV into a DataFrame
    df = pd.read_csv(file_path)
    
    # Filter the DataFrame based on the 'area' column
    if 'area' in df.columns:
        filtered_df = df[df['area'].isin(target_areas)].copy()  # Create a copy to avoid SettingWithCopyWarning
        
        
        # Check if the DataFrame is not empty before saving
        if not filtered_df.empty:
            output_path = os.path.join(output_folder, file_name)
            filtered_df.to_csv(output_path, index=False)
            print(f"Filtered data saved to: {output_path}")
        else:
            print(f"Filtered DataFrame for {file_name} is empty. Skipping save.")
    else:
        print(f"Column 'area' not found in {file_name}. Skipping file.")
# Out:
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201810.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201811.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201901.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201902.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201903.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201905.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201909.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201910.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201911.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201914.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\201915.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202001.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202002.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202003.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202004.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202005.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202006u.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202007.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202008.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202011.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202014.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202015.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202016.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202105.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202107.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202110.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202114.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202117.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202118.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202201.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202202.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202205.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202207.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202208.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202212.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202215.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202216.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202217.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202302.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202306.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202307.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202308.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202309.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202311.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202314a.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202401.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202404.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202405.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202407.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202408.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202409.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202413a.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202414.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202416.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202417.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202418.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202421.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202422.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202501.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202503.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202504.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202505.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202507.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202508.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202510.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202511.csv
# Filtered data saved to: 3_brain_visualization_preProcessing_2\202512.csv
